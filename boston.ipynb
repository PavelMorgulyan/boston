# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy

from sklearn import metrics as metrics
from sklearn import datasets as datasets
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
boston = datasets.load_boston()
data = pd.DataFrame(data = np.c_[boston['data'], boston['target']], columns = np.append(boston['feature_names'], 'target'))

# %%
import numpy as np

# %%
boston = datasets.load_boston()
data = pd.DataFrame(data = np.c_[boston['data'], boston['target']], columns = np.append(boston['feature_names'], 'target'))

# %%
print(data)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
models = {
    'LinearRegression': LinearRegression(),
    'DecisionTreeRegressor': DecisionTreeRegressor(random_state=0),
    'RandomForestRegressor': RandomForestRegressor(random_state=0)
}

# %%
def var(y_predict):
    return np.var(y_predict)

# %%
def bias2(y, y_predict):
    return np.mean((y- np.mean(y_predict)) ** 2)

# %%
def error(y, y_predict):
    return np.mean((y - y_predict) ** 2)

# %%
results = {'Model': [], 'Var': [], 'Bias': [], 'Error': []}
for name, model in models.items():
    m = model.fit(x_train, y_train)
    y_pred = m.predict(x_test),flatten()
    results['Model'].append(name)
    results['Var'].append(var(y_pred))
    results['Bias'].append(bias(y_test.to_numpy(), y_pred))
    results['Error'].append(error(y_test.to_numpy(), y_pred))
pd.DataFrame.from_dict(results)

# %%
x = data.drop([‘target’, axis=1)
y=data[[‘target’]]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.33, random_state=1)

# %%
x = data.drop(['target', axis=1)
y=data[['target']]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.33, random_state=1)

# %%
x = data.drop(['target'], axis=1)
y=data[['target']]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.33, random_state=1)

# %%
results = {'Model': [], 'Var': [], 'Bias': [], 'Error': []}
for name, model in models.items():
    m = model.fit(x_train, y_train)
    y_pred = m.predict(x_test).flatten()
    results['Model'].append(name)
    results['Var'].append(var(y_pred))
    results['Bias'].append(bias2(y_test.to_numpy(), y_pred))
    results['Error'].append(error(y_test.to_numpy(), y_pred))
pd.DataFrame.from_dict(results)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
#                    Model        Var       Bias       Error
# 0       LinearRegression  56.550855  88.141029  144.691884
# 1  DecisionTreeRegressor  88.198522  88.109360  176.307882
# 2  RandomForestRegressor  68.795745  88.099676  156.895421
